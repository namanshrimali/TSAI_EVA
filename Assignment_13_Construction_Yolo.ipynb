# %%
# !git clone https://github.com/namanshrimali/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 173 (delta 6), reused 5 (delta 2), pack-reused 156
# Receiving objects: 100% (173/173), 12.76 MiB | 47.16 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# removing existing customdata and adding our extracted zip file
# !rm -rf /content/YoloV3/data/customdata/

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.8.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
import zipfile
start_time =  time.time()

DATA_PATH = r'/content/drive/MyDrive/construction_yolo/data.zip'

zip_ref = zipfile.ZipFile(DATA_PATH, 'r')
zip_ref.extractall("/content/YoloV3")

print(f'Dataset extracted in {time.time()- start_time} seconds')
# Out:
# Dataset extracted in 10.782265424728394 seconds

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png

# %%
# !mkdir weights
# !touch yolov3-spp-ultralytics.pt
# !cp "/content/drive/MyDrive/construction_yolo/yolov3-spp-ultralytics.pt" "/content/YoloV3/weights/yolov3-spp-ultralytics.pt" -v
# Out:
# '/content/drive/MyDrive/construction_yolo/yolov3-spp-ultralytics.pt' -> '/content/YoloV3/weights/yolov3-spp-ultralytics.pt'

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# 2021-03-20 07:57:35.496563: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 3243.98it/s]
# ...

# %%
# !python train.py --data /content/YoloV3/data/assignment13/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 100 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='/content/YoloV3/data/assignment13/custom.data', device='', epochs=100, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# 2021-03-20 07:58:27.943376: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# ...

# %%
# !cp "/content/drive/MyDrive/construction_yolo/best.pt" "/content/YoloV3/weights/last.pt" -v
# Out:
# '/content/drive/MyDrive/construction_yolo/best.pt' -> '/content/YoloV3/weights/last.pt'

# %%
# video_path = ''
# !python detect.py --conf-thres 0.1 --source /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4 --output out_out
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (815/5812) /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4: 320x512 1 vests, Done. (0.016s)
# video 1/1 (816/5812) /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4: 320x512 1 vests, Done. (0.017s)
# video 1/1 (817/5812) /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4: 320x512 1 vests, Done. (0.016s)
# video 1/1 (818/5812) /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4: 320x512 1 vests, Done. (0.016s)
# video 1/1 (819/5812) /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4: 320x512 1 vests, Done. (0.017s)
# video 1/1 (820/5812) /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4: 320x512 1 vests, Done. (0.016s)
# video 1/1 (821/5812) /content/drive/MyDrive/construction_yolo/covid_construction_safety.mp4: 320x512 1 vests, Done. (0.017s)
# ...

# %%
import glob
video_output = glob.glob('/content/YoloV3/out_out/*.mp4')[0]
print(video_output)
# Out:
# /content/YoloV3/out_out/covid_construction_safety.mp4

# %%
# !cp "/content/drive/MyDrive/construction_yolo/final_video.mp4" video_output
# Out:
# cp: cannot stat '/content/drive/MyDrive/construction_yolo/final_video.mp4': No such file or directory
